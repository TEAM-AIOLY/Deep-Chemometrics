# %%
# %load_ext autoreload
# %autoreload 2
import torch 
import os
import numpy as np
import scipy as sp
import utils
from torch import nn
from torch.nn import functional as F
from torch import optim
from net.chemtools.PLS import PLS
from net.base_net import CuiNet , Darionet
from utils.testing import ccc,r2_score,RMSEP
import matplotlib.pyplot as plt
from utils.training import train_optuna
from data.load_dataset_atonce import MangoDataset

from utils.testing import test
import torch.utils.data as data_utils
from sklearn.model_selection import train_test_split

# %%
data = sp.io.loadmat("data/dataset/Mango/mango_dm_full_outlier_removed2.mat")
print(data.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'DM_cal', 'DM_test', 'Sp_cal', 'Sp_test', 'wave', 'SP_all_test', 'SP_all_train'])

# %%
Ycal = data["DM_cal"]
Ytest = data["DM_test"]
Xcal = data["SP_all_train"]
Xtest = data["SP_all_test"]

# %%
plt.figure(figsize=(10,6))
plt.subplot(221)
plt.title('Train data')
plt.plot(Xcal.T)
plt.ylabel('Amplitude (a.u)')
plt.xlabel('Variable Index')
plt.subplot(222)
plt.title('Test data')
plt.plot(Xtest.T)
plt.ylabel('Amplitude (a.u)')
plt.xlabel('Variable Index')
plt.subplot(223)
plt.plot(data['DM_cal'])
plt.ylabel('Dry Matter (%)')
plt.xlabel('Sample number')
plt.subplot(224)
plt.plot(data['DM_test'])
plt.ylabel('Dry Matter (%)')
plt.xlabel('Sample number')
plt.tight_layout()
plt.show()

# %%
## Spliting the train set 
x_cal, x_val, y_cal, y_val = train_test_split(Xcal, Ycal, test_size=0.20, shuffle=True, random_state=42) 

## The wavelenghts for the XX axis when we plot the spectra
x_scale=data['wave'].astype(np.float32).reshape(-1,1)

## Check for dimensions
print('Data set dimensions ----------------------------')
print('Full Train set dims X Y = {}\t{}'.format(Xcal.shape, Ycal.shape))
print('Calibration set dims X Y = {}\t{}'.format(x_cal.shape, y_cal.shape))
print('val set dims X Y = {}\t{}'.format(x_val.shape, y_val.shape))
print('Test set dims X Y = {}\t{}'.format(Xtest.shape, Ytest.shape))
print('wavelengths number = {}'.format(np.shape(x_scale)))
# Out:
# Data set dimensions ----------------------------
# Full Train set dims X Y = (9914, 618)	(9914, 1)
# Calibration set dims X Y = (7931, 618)	(7931, 1)
# val set dims X Y = (1983, 618)	(1983, 1)
# Test set dims X Y = (1448, 618)	(1448, 1)
# wavelengths number = (103, 1)

# %%
## Visual data sanity checking for the test set
plt.figure(figsize=(16,4))
plt.subplot(1,2,1)
plt.plot(x_val[:50,:].T,'k')
plt.title('First 50 spectra from the val sample')
plt.xlabel(r'$\lambda$ (nm)')
plt.ylabel('Spectra intensity')
plt.subplot(1,2,2)
plt.title('Y labels')
plt.plot(y_val,'k.')
plt.xlabel('Sample number')
plt.ylabel('Dry Matter (%)')
plt.show()

# %%
# calculate mean and std per column

mean = np.mean(x_cal, axis=0)
std = np.std(x_cal, axis=0)

# Convert np.array to Dataloader 
# add dt in loader 

cal = MangoDataset(x_cal,y_cal)
val = data_utils.TensorDataset(torch.Tensor(x_val), torch.Tensor(y_val))
test_dt = data_utils.TensorDataset(torch.Tensor(Xtest), torch.Tensor(Ytest))

# %%
# plot first spectrum output of the cal dataset
x,y = next(iter(cal))
plt.plot(x)
plt.show()

# %%
# define model parameters 

model_name ="_DarioNet_Mango"  
spec_dims = x_cal.shape[1]

num_epochs = 1000
save_interval = 10
BATCH = 128
FILTER_SIZE = 45
L2_BETA = 0.015
LR = 0.002
p = 0.02
data_path ="data/dataset/Mango/mango_dm_full_outlier_removed2.mat"
save_path = os.path.dirname(os.path.abspath(data_path)) + f'/models/{model_name}/' + model_name
print(save_path)
cal_loader = data_utils.DataLoader(cal, batch_size=BATCH, shuffle=True)
val_loader = data_utils.DataLoader(val, batch_size=BATCH, shuffle=True)
test_loader = data_utils.DataLoader(test_dt, batch_size=BATCH, shuffle=True)

model2 = Darionet(mean = mean,std = std, out_dims=1,filter_size = FILTER_SIZE, reg_beta = L2_BETA, input_dims = spec_dims, p = p)

optimizer = optim.Adam(model2.parameters(), lr=LR, weight_decay=L2_BETA)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min',patience=25, factor=0.5, min_lr=1e-6, 
                                                       verbose=True)

criterion = nn.MSELoss(reduction='none')
print(model2)
# Out:
# /home/metz/deepchemometrics/Aioly_v2/Deep-Chemometrics/data/dataset/Mango/models/_DarioNet_Mango/_DarioNet_Mango
# Darionet(
#   (conv1): Conv1d(1, 1, kernel_size=(45,), stride=(1,), padding=same)
#   (fc1): Linear(in_features=618, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=16, bias=True)
#   (dropout): ManualDropout()
#   (output_layer): Linear(in_features=16, out_features=1, bias=True)
# )

# %%
# Train model
train_losses, val_losses,val_r2_scores, final_path =train_optuna(model2, optimizer, criterion, cal_loader, val_loader,None, num_epochs, save_path=save_path, save_interval=save_interval)
# Out:
# 0.5420621633529663
# Epoch 1/1000 | Train Losses: y 0: 32.9822 | Validation Losses: y 0: 3.5371 | R2 Scores: y 0: 0.5421 | LR: 0.002
# 0.6331548094749451
# Epoch 2/1000 | Train Losses: y 0: 2.7871 | Validation Losses: y 0: 2.1175 | R2 Scores: y 0: 0.6332 | LR: 0.002
# 0.6839014291763306
# Epoch 3/1000 | Train Losses: y 0: 1.7629 | Validation Losses: y 0: 1.8356 | R2 Scores: y 0: 0.6839 | LR: 0.002
# 0.7117629051208496
# Epoch 4/1000 | Train Losses: y 0: 1.6057 | Validation Losses: y 0: 1.5072 | R2 Scores: y 0: 0.7118 | LR: 0.002
# 0.7592731714248657
# Epoch 5/1000 | Train Losses: y 0: 1.3897 | Validation Losses: y 0: 1.3703 | R2 Scores: y 0: 0.7593 | LR: 0.002
# 0.7997989654541016
# Epoch 6/1000 | Train Losses: y 0: 1.3729 | Validation Losses: y 0: 1.1474 | R2 Scores: y 0: 0.7998 | LR: 0.002
# 0.780332088470459
# Epoch 7/1000 | Train Losses: y 0: 1.2114 | Validation Losses: y 0: 1.2513 | R2 Scores: y 0: 0.7803 | LR: 0.002
# 0.7897360324859619
# Epoch 8/1000 | Train Losses: y 0: 1.1742 | Validation Losses: y 0: 1.1462 | R2 Scores: y 0: 0.7897 | LR: 0.002
# 0.7982655763626099
# Epoch 9/1000 | Train Losses: y 0: 1.1605 | Validation Losses: y 0: 1.1771 | R2 Scores: y 0: 0.7983 | LR: 0.002
# 0.7811852097511292
# Epoch 10/1000 | Train Losses: y 0: 1.1366 | Validation Losses: y 0: 1.3585 | R2 Scores: y 0: 0.7812 | LR: 0.002
# Model saved at epoch 10 to /home/metz/deepchemometrics/Aioly_v2/Deep-Chemometrics/data/dataset/Mango/models/_DarioNet_Mango/_DarioNet_Mango_epoch_10.pth
# 0.8082849383354187
# Epoch 11/1000 | Train Losses: y 0: 1.1150 | Validation Losses: y 0: 1.0723 | R2 Scores: y 0: 0.8083 | LR: 0.002
# 0.7948592305183411
# Epoch 12/1000 | Train Losses: y 0: 1.1144 | Validation Losses: y 0: 1.1145 | R2 Scores: y 0: 0.7949 | LR: 0.002
# 0.821273684501648
# Epoch 13/1000 | Train Losses: y 0: 1.1131 | Validation Losses: y 0: 1.0564 | R2 Scores: y 0: 0.8213 | LR: 0.002
# 0.7938042283058167
# Epoch 14/1000 | Train Losses: y 0: 1.0247 | Validation Losses: y 0: 1.0510 | R2 Scores: y 0: 0.7938 | LR: 0.002
# 0.7938149571418762
# Epoch 15/1000 | Train Losses: y 0: 1.0468 | Validation Losses: y 0: 1.1373 | R2 Scores: y 0: 0.7938 | LR: 0.002
# 0.8072540760040283
# Epoch 16/1000 | Train Losses: y 0: 1.1031 | Validation Losses: y 0: 1.1067 | R2 Scores: y 0: 0.8073 | LR: 0.002
# 0.8224524259567261
# Epoch 17/1000 | Train Losses: y 0: 1.1049 | Validation Losses: y 0: 1.1548 | R2 Scores: y 0: 0.8225 | LR: 0.002
# 0.8023375272750854
# Epoch 18/1000 | Train Losses: y 0: 1.0629 | Validation Losses: y 0: 1.1328 | R2 Scores: y 0: 0.8023 | LR: 0.002
# 0.8122628927230835
# Epoch 19/1000 | Train Losses: y 0: 1.0562 | Validation Losses: y 0: 1.0976 | R2 Scores: y 0: 0.8123 | LR: 0.002
# 0.7976126670837402
# Epoch 20/1000 | Train Losses: y 0: 1.0603 | Validation Losses: y 0: 1.0748 | R2 Scores: y 0: 0.7976 | LR: 0.002
# Model saved at epoch 20 to /home/metz/deepchemometrics/Aioly_v2/Deep-Chemometrics/data/dataset/Mango/models/_DarioNet_Mango/_DarioNet_Mango_epoch_20.pth
# 0.823677122592926
# Epoch 21/1000 | Train Losses: y 0: 0.9684 | Validation Losses: y 0: 1.0282 | R2 Scores: y 0: 0.8237 | LR: 0.002
# 0.8045324087142944
# Epoch 22/1000 | Train Losses: y 0: 1.0052 | Validation Losses: y 0: 1.0345 | R2 Scores: y 0: 0.8045 | LR: 0.002
# 0.8225394487380981
# Epoch 23/1000 | Train Losses: y 0: 1.0218 | Validation Losses: y 0: 1.0320 | R2 Scores: y 0: 0.8225 | LR: 0.002
# 0.7693044543266296
# Epoch 24/1000 | Train Losses: y 0: 1.0330 | Validation Losses: y 0: 1.1212 | R2 Scores: y 0: 0.7693 | LR: 0.002
# 0.8053568005561829
# Epoch 25/1000 | Train Losses: y 0: 1.0268 | Validation Losses: y 0: 1.0071 | R2 Scores: y 0: 0.8054 | LR: 0.002
# 0.8338919878005981
# Epoch 26/1000 | Train Losses: y 0: 0.9761 | Validation Losses: y 0: 1.0186 | R2 Scores: y 0: 0.8339 | LR: 0.002
# 0.8286237120628357
# Epoch 27/1000 | Train Losses: y 0: 1.0075 | Validation Losses: y 0: 1.0088 | R2 Scores: y 0: 0.8286 | LR: 0.002
# 0.813836395740509
# Epoch 28/1000 | Train Losses: y 0: 0.9958 | Validation Losses: y 0: 1.0462 | R2 Scores: y 0: 0.8138 | LR: 0.002
# 0.8344398736953735
# Epoch 29/1000 | Train Losses: y 0: 0.9602 | Validation Losses: y 0: 0.9859 | R2 Scores: y 0: 0.8344 | LR: 0.002
# 0.8451624512672424
# Epoch 30/1000 | Train Losses: y 0: 0.9911 | Validation Losses: y 0: 0.9121 | R2 Scores: y 0: 0.8452 | LR: 0.002
# Model saved at epoch 30 to /home/metz/deepchemometrics/Aioly_v2/Deep-Chemometrics/data/dataset/Mango/models/_DarioNet_Mango/_DarioNet_Mango_epoch_30.pth
# 0.831756591796875
# Epoch 31/1000 | Train Losses: y 0: 1.0141 | Validation Losses: y 0: 1.0492 | R2 Scores: y 0: 0.8318 | LR: 0.002
# 0.8233858346939087
# Epoch 32/1000 | Train Losses: y 0: 0.9639 | Validation Losses: y 0: 1.0326 | R2 Scores: y 0: 0.8234 | LR: 0.002
# 0.826221227645874
# Epoch 33/1000 | Train Losses: y 0: 0.9665 | Validation Losses: y 0: 0.9340 | R2 Scores: y 0: 0.8262 | LR: 0.002
# 0.8240491151809692
# Epoch 34/1000 | Train Losses: y 0: 0.9672 | Validation Losses: y 0: 0.9399 | R2 Scores: y 0: 0.8240 | LR: 0.002
# 0.8108154535293579
# Epoch 35/1000 | Train Losses: y 0: 0.9885 | Validation Losses: y 0: 0.9675 | R2 Scores: y 0: 0.8108 | LR: 0.002
# 0.8109830617904663
# Epoch 36/1000 | Train Losses: y 0: 0.9222 | Validation Losses: y 0: 1.0020 | R2 Scores: y 0: 0.8110 | LR: 0.002
# 0.7541812658309937
# Epoch 37/1000 | Train Losses: y 0: 0.9523 | Validation Losses: y 0: 1.1813 | R2 Scores: y 0: 0.7542 | LR: 0.002
# 0.7993580102920532
# Epoch 38/1000 | Train Losses: y 0: 1.0147 | Validation Losses: y 0: 1.0005 | R2 Scores: y 0: 0.7994 | LR: 0.002
# 0.8347715735435486
# Epoch 39/1000 | Train Losses: y 0: 0.9809 | Validation Losses: y 0: 0.9659 | R2 Scores: y 0: 0.8348 | LR: 0.002
# 0.8229789733886719
# Epoch 40/1000 | Train Losses: y 0: 0.9128 | Validation Losses: y 0: 0.9234 | R2 Scores: y 0: 0.8230 | LR: 0.002
# Model saved at epoch 40 to /home/metz/deepchemometrics/Aioly_v2/Deep-Chemometrics/data/dataset/Mango/models/_DarioNet_Mango/_DarioNet_Mango_epoch_40.pth
# 0.8385403752326965
# Epoch 41/1000 | Train Losses: y 0: 0.9635 | Validation Losses: y 0: 0.8300 | R2 Scores: y 0: 0.8385 | LR: 0.002
# 0.8290991187095642
# Epoch 42/1000 | Train Losses: y 0: 0.9186 | Validation Losses: y 0: 0.9358 | R2 Scores: y 0: 0.8291 | LR: 0.002
# 0.8482570648193359
# Epoch 43/1000 | Train Losses: y 0: 0.8501 | Validation Losses: y 0: 0.8837 | R2 Scores: y 0: 0.8483 | LR: 0.002
# 0.8216458559036255
# Epoch 44/1000 | Train Losses: y 0: 0.9446 | Validation Losses: y 0: 0.9540 | R2 Scores: y 0: 0.8216 | LR: 0.002
# 0.8458837270736694
# Epoch 45/1000 | Train Losses: y 0: 0.8888 | Validation Losses: y 0: 1.0014 | R2 Scores: y 0: 0.8459 | LR: 0.002
# 0.8300474286079407
# Epoch 46/1000 | Train Losses: y 0: 0.9634 | Validation Losses: y 0: 0.8994 | R2 Scores: y 0: 0.8300 | LR: 0.002
to /home/metz/deepchemometrics/Aioly_v2/Deep-Chemometrics/data/dataset/Mango/models/_DarioNet_Mango/_DarioNet_Mango_epoch_300.pth
# 0.8540935516357422
# Epoch 301/1000 | Train Losses: y 0: 0.6791 | Validation Losses: y 0: 0.7702 | R2 Scores: y 0: 0.8541 | LR: 0.002
# 0.8638424873352051
# Epoch 302/1000 | Train Losses: y 0: 0.6983 | Validation Losses: y 0: 0.7175 | R2 Scores: y 0: 0.8638 | LR: 0.002
# 0.8474125862121582
# Epoch 303/1000 | Train Losses: y 0: 0.6858 | Validation Losses: y 0: 0.7711 | R2 Scores: y 0: 0.8474 | LR: 0.002
# 0.8662057518959045
# Epoch 304/1000 | Train Losses: y 0: 0.7096 | Validation Losses: y 0: 0.7477 | R2 Scores: y 0: 0.8662 | LR: 0.002
# 0.8615800142288208
# Epoch 305/1000 | Train Losses: y 0: 0.7240 | Validation Losses: y 0: 0.6947 | R2 Scores: y 0: 0.8616 | LR: 0.002
# 0.8376641869544983
# Epoch 306/1000 | Train Losses: y 0: 0.6652 | Validation Losses: y 0: 0.7913 | R2 Scores: y 0: 0.8377 | LR: 0.002
# 0.8520967960357666
# Epoch 307/1000 | Train Losses: y 0: 0.7098 | Validation Losses: y 0: 0.7818 | R2 Scores: y 0: 0.8521 | LR: 0.002
# 0.8653143644332886
# Epoch 308/1000 | Train Losses: y 0: 0.7182 | Validation Losses: y 0: 0.7337 | R2 Scores: y 0: 0.8653 | LR: 0.002
# 0.864265501499176
# Epoch 309/1000 | Train Losses: y 0: 0.7188 | Validation Losses: y 0: 0.7074 | R2 Scores: y 0: 0.8643 | LR: 0.002
# 0.8723517060279846
# Epoch 310/1000 | Train Losses: y 0: 0.6892 | Validation Losses: y 0: 0.7129 | R2 Scores: y 0: 0.8724 | LR: 0.002
# Model saved at epoch 310 to /home/metz/deepchemometrics/Aioly_v2/Deep-Chemometrics/data/dataset/Mango/models/_DarioNet_Mango/_DarioNet_Mango_epoch_310.pth
# 0.8621797561645508
# Epoch 311/1000 | Train Losses: y 0: 0.7115 | Validation Losses: y 0: 0.8084 | R2 Scores: y 0: 0.8622 | LR: 0.002
# 0.8498888611793518
# Epoch 312/1000 | Train Losses: y 0: 0.6832 | Validation Losses: y 0: 0.7694 | R2 Scores: y 0: 0.8499 | LR: 0.002
# 0.8807380199432373
# Epoch 313/1000 | Train Losses: y 0: 0.7105 | Validation Losses: y 0: 0.6899 | R2 Scores: y 0: 0.8807 | LR: 0.002
# 0.8607880473136902
# Epoch 314/1000 | Train Losses: y 0: 0.6841 | Validation Losses: y 0: 0.7938 | R2 Scores: y 0: 0.8608 | LR: 0.002
# 0.8549820184707642
# Epoch 315/1000 | Train Losses: y 0: 0.7108 | Validation Losses: y 0: 0.7813 | R2 Scores: y 0: 0.8550 | LR: 0.002
# 0.8587758541107178
# Epoch 316/1000 | Train Losses: y 0: 0.7342 | Validation Losses: y 0: 0.7495 | R2 Scores: y 0: 0.8588 | LR: 0.002
# 0.8588221669197083
# Epoch 317/1000 | Train Losses: y 0: 0.7209 | Validation Losses: y 0: 0.8550 | R2 Scores: y 0: 0.8588 | LR: 0.002
# 0.8520703315734863
# Epoch 318/1000 | Train Losses: y 0: 0.7209 | Validation Losses: y 0: 0.7552 | R2 Scores: y 0: 0.8521 | LR: 0.002
# 0.8578737378120422
# Epoch 319/1000 | Train Losses: y 0: 0.6807 | Validation Losses: y 0: 0.7964 | R2 Scores: y 0: 0.8579 | LR: 0.002
# 0.8762587308883667
# Epoch 320/1000 | Train Losses: y 0: 0.6838 | Validation Losses: y 0: 0.7357 | R2 Scores: y 0: 0.8763 | LR: 0.002
# Model saved at epoch 320 to /home/metz/deepchemometrics/Aioly_v2/Deep-Chemometrics/data/dataset/Mango/models/_DarioNet_Mango/_DarioNet_Mango_epoch_320.pth
# 0.8582485914230347
# Epoch 321/1000 | Train Losses: y 0: 0.6721 | Validation Losses: y 0: 0.7309 | R2 Scores: y 0: 0.8582 | LR: 0.002
# 0.8686748743057251
# Epoch 322/1000 | Train Losses: y 0: 0.7113 | Validation Losses: y 0: 0.7232 | R2 Scores: y 0: 0.8687 | LR: 0.002
# 0.8614453673362732
# Epoch 323/1000 | Train Losses: y 0: 0.6855 | Validation Losses: y 0: 0.7713 | R2 Scores: y 0: 0.8614 | LR: 0.002
# 0.8563488721847534
# Epoch 324/1000 | Train Losses: y 0: 0.7254 | Validation Losses: y 0: 0.7550 | R2 Scores: y 0: 0.8563 | LR: 0.002
# 0.876680850982666
# Epoch 325/1000 | Train Losses: y 0: 0.6968 | Validation Losses: y 0: 0.7030 | R2 Scores: y 0: 0.8767 | LR: 0.002
# 0.8611640930175781
# Epoch 326/1000 | Train Losses: y 0: 0.7045 | Validation Losses: y 0: 0.7292 | R2 Scores: y 0: 0.8612 | LR: 0.002
# 0.8506903648376465
# Epoch 327/1000 | Train Losses: y 0: 0.6852 | Validation Losses: y 0: 0.7761 | R2 Scores: y 0: 0.8507 | LR: 0.002
# 0.870716392993927
# ...
# 0.8642939329147339
# Epoch 749/1000 | Train Losses: y 0: 0.6843 | Validation Losses: y 0: 0.7311 | R2 Scores: y 0: 0.8643 | LR: 0.002
# 0.8734705448150635
# Epoch 750/1000 | Train Losses: y 0: 0.6921 | Validation Losses: y 0: 0.7017 | R2 Scores: y 0: 0.8735 | LR: 0.002
# Model saved at epoch 750 to /home/metz/deepchemometrics/Aioly_v2/Deep-Chemometrics/data/dataset/Mango/models/_DarioNet_Mango/_DarioNet_Mango_epoch_750.pth
# 0.8633188009262085
# Epoch 751/1000 | Train Losses: y 0: 0.6812 | Validation Losses: y 0: 0.6906 | R2 Scores: y 0: 0.8633 | LR: 0.002
# 0.8816688060760498
# Epoch 752/1000 | Train Losses: y 0: 0.6615 | Validation Losses: y 0: 0.7089 | R2 Scores: y 0: 0.8817 | LR: 0.002
# 0.8709571957588196
# Epoch 753/1000 | Train Losses: y 0: 0.6689 | Validation Losses: y 0: 0.7348 | R2 Scores: y 0: 0.8710 | LR: 0.002
# 0.8768334984779358
# Epoch 754/1000 | Train Losses: y 0: 0.6609 | Validation Losses: y 0: 0.6948 | R2 Scores: y 0: 0.8768 | LR: 0.002
# 0.8733834624290466
# Epoch 755/1000 | Train Losses: y 0: 0.6566 | Validation Losses: y 0: 0.6935 | R2 Scores: y 0: 0.8734 | LR: 0.002
# 0.8563644289970398
# Epoch 756/1000 | Train Losses: y 0: 0.6736 | Validation Losses: y 0: 0.7287 | R2 Scores: y 0: 0.8564 | LR: 0.002
# 0.8667967319488525
# Epoch 757/1000 | Train Losses: y 0: 0.6620 | Validation Losses: y 0: 0.7130 | R2 Scores: y 0: 0.8668 | LR: 0.002
# 0.8688862919807434
# Epoch 758/1000 | Train Losses: y 0: 0.6831 | Validation Losses: y 0: 0.7122 | R2 Scores: y 0: 0.8689 | LR: 0.002
# 0.8852241635322571
# Epoch 759/1000 | Train Losses: y 0: 0.6679 | Validation Losses: y 0: 0.6729 | R2 Scores: y 0: 0.8852 | LR: 0.002
# 0.8591728210449219
# Epoch 760/1000 | Train Losses: y 0: 0.6796 | Validation Losses: y 0: 0.7104 | R2 Scores: y 0: 0.8592 | LR: 0.002
# Model saved at epoch 760 to /home/metz/deepchemometrics/Aioly_v2/Deep-Chemometrics/data/dataset/Mango/models/_DarioNet_Mango/_DarioNet_Mango_epoch_760.pth
# 0.8737017512321472
# Epoch 761/1000 | Train Losses: y 0: 0.6820 | Validation Losses: y 0: 0.7085 | R2 Scores: y 0: 0.8737 | LR: 0.002
# 0.8624028563499451
# Epoch 762/1000 | Train Losses: y 0: 0.6913 | Validation Losses: y 0: 0.6918 | R2 Scores: y 0: 0.8624 | LR: 0.002
# 0.8608285784721375
# Epoch 763/1000 | Train Losses: y 0: 0.6773 | Validation Losses: y 0: 0.7392 | R2 Scores: y 0: 0.8608 | LR: 0.002
# 0.8773216605186462
# Epoch 764/1000 | Train Losses: y 0: 0.6819 | Validation Losses: y 0: 0.6952 | R2 Scores: y 0: 0.8773 | LR: 0.002
# 0.8734385371208191
# Epoch 765/1000 | Train Losses: y 0: 0.6761 | Validation Losses: y 0: 0.6814 | R2 Scores: y 0: 0.8734 | LR: 0.002
# 0.8812440633773804
# Epoch 766/1000 | Train Losses: y 0: 0.6763 | Validation Losses: y 0: 0.6835 | R2 Scores: y 0: 0.8812 | LR: 0.002
# 0.885056734085083
# Epoch 767/1000 | Train Losses: y 0: 0.7038 | Validation Losses: y 0: 0.7090 | R2 Scores: y 0: 0.8851 | LR: 0.002
# 0.8704468011856079
# Epoch 768/1000 | Train Losses: y 0: 0.6963 | Validation Losses: y 0: 0.7164 | R2 Scores: y 0: 0.8704 | LR: 0.002
# 0.8672848343849182
# Epoch 769/1000 | Train Losses: y 0: 0.6742 | Validation Losses: y 0: 0.7311 | R2 Scores: y 0: 0.8673 | LR: 0.002
# 0.8600873947143555
# Epoch 770/1000 | Train Losses: y 0: 0.6569 | Validation Losses: y 0: 0.7723 | R2 Scores: y 0: 0.8601 | LR: 0.002
# Model saved at epoch 770 to /home/metz/deepchemometrics/Aioly_v2/Deep-Chemometrics/data/dataset/Mango/models/_DarioNet_Mango/_DarioNet_Mango_epoch_770.pth
# 0.8689343929290771
# Epoch 771/1000 | Train Losses: y 0: 0.6885 | Validation Losses: y 0: 0.7388 | R2 Scores: y 0: 0.8689 | LR: 0.002
# 0.8692094087600708
# Epoch 772/1000 | Train Losses: y 0: 0.6594 | Validation Losses: y 0: 0.7287 | R2 Scores: y 0: 0.8692 | LR: 0.002
# 0.8545776605606079
# Epoch 773/1000 | Train Losses: y 0: 0.6682 | Validation Losses: y 0: 0.7163 | R2 Scores: y 0: 0.8546 | LR: 0.002
# 0.8690906763076782
# Epoch 774/1000 | Train Losses: y 0: 0.6718 | Validation Losses: y 0: 0.7011 | R2 Scores: y 0: 0.8691 | LR: 0.002
# 0.8733853697776794
# Epoch 793/1000 | Train Losses: y 0: 0.7080 | Validation Losses: y 0: 0.7786 | R2 Scores: y 0: 0.8596 | LR: 0.002
# 0.8682131767272949
# Epoch 794/1000 | Train Losses: y 0: 0.6811 | Validation Losses: y 0: 0.6913 | R2 Scores: y 0: 0.8682 | LR: 0.002
# 0.8649973273277283
# Epoch 795/1000 | Train Losses: y 0: 0.6828 | Validation Losses: y 0: 0.7221 | R2 Scores: y 0: 0.8650 | LR: 0.002
# 0.8463839292526245
# Epoch 796/1000 | Train Losses: y 0: 0.6731 | Validation Losses: y 0: 0.7355 | R2 Scores: y 0: 0.8464 | LR: 0.002
# 0.8552798628807068
# Epoch 797/1000 | Train Losses: y 0: 0.6728 | Validation Losses: y 0: 0.7613 | R2 Scores: y 0: 0.8553 | LR: 0.002
# 0.8831984996795654
# Epoch 798/1000 | Train Losses: y 0: 0.6571 | Validation Losses: y 0: 0.7157 | R2 Scores: y 0: 0.8832 | LR: 0.002
# 0.8557120561599731
# Epoch 799/1000 | Train Losses: y 0: 0.6685 | Validation Losses: y 0: 0.7719 | R2 Scores: y 0: 0.8557 | LR: 0.002
# 0.8605249524116516
# Epoch 800/1000 | Train Losses: y 0: 0.6518 | Validation Losses: y 0: 0.6984 | R2 Scores: y 0: 0.8605 | LR: 0.002
# Model saved at epoch 800 to /home/metz/deepchemometrics/Aioly_v2/Deep-Chemometrics/data/dataset/Mango/models/_DarioNet_Mango/_DarioNet_Mango_epoch_800.pth
# 0.8737257719039917
# Epoch 801/1000 | Train Losses: y 0: 0.6995 | Validation Losses: y 0: 0.6931 | R2 Scores: y 0: 0.8737 | LR: 0.002
# 0.8804402947425842
# Epoch 802/1000 | Train Losses: y 0: 0.6844 | Validation Losses: y 0: 0.7177 | R2 Scores: y 0: 0.8804 | LR: 0.002
# 0.8715468645095825
# Epoch 803/1000 | Train Losses: y 0: 0.6711 | Validation Losses: y 0: 0.7555 | R2 Scores: y 0: 0.8715 | LR: 0.002
# 0.8593116402626038
# Epoch 804/1000 | Train Losses: y 0: 0.6587 | Validation Losses: y 0: 0.7255 | R2 Scores: y 0: 0.8593 | LR: 0.002
# 0.8701801896095276
# Epoch 805/1000 | Train Losses: y 0: 0.6570 | Validation Losses: y 0: 0.6934 | R2 Scores: y 0: 0.8702 | LR: 0.002
# 0.8582242131233215
# Epoch 806/1000 | Train Losses: y 0: 0.6714 | Validation Losses: y 0: 0.7502 | R2 Scores: y 0: 0.8582 | LR: 0.002
# 0.8457568883895874
# Epoch 807/1000 | Train Losses: y 0: 0.6635 | Validation Losses: y 0: 0.8263 | R2 Scores: y 0: 0.8458 | LR: 0.002
# 0.8621578216552734
# Epoch 808/1000 | Train Losses: y 0: 0.7047 | Validation Losses: y 0: 0.7129 | R2 Scores: y 0: 0.8622 | LR: 0.002
# 0.8779710531234741
# Epoch 809/1000 | Train Losses: y 0: 0.6640 | Validation Losses: y 0: 0.6696 | R2 Scores: y 0: 0.8780 | LR: 0.002
# 0.8743865489959717
# Epoch 810/1000 | Train Losses: y 0: 0.6806 | Validation Losses: y 0: 0.6695 | R2 Scores: y 0: 0.8744 | LR: 0.002
# Model saved at epoch 810 to /home/metz/deepchemometrics/Aioly_v2/Deep-Chemometrics/data/dataset/Mango/models/_DarioNet_Mango/_DarioNet_Mango_epoch_810.pth
# 0.8664515018463135
# Epoch 811/1000 | Train Losses: y 0: 0.7175 | Validation Losses: y 0: 0.7224 | R2 Scores: y 0: 0.8665 | LR: 0.002
# 0.8673403263092041
# Epoch 812/1000 | Train Losses: y 0: 0.6996 | Validation Losses: y 0: 0.7080 | R2 Scores: y 0: 0.8673 | LR: 0.002
# 0.8782097101211548
# Epoch 813/1000 | Train Losses: y 0: 0.6932 | Validation Losses: y 0: 0.6957 | R2 Scores: y 0: 0.8782 | LR: 0.002
# 0.8562177419662476
# Epoch 814/1000 | Train Losses: y 0: 0.6718 | Validation Losses: y 0: 0.7618 | R2 Scores: y 0: 0.8562 | LR: 0.002
# 0.865242063999176
# Epoch 815/1000 | Train Losses: y 0: 0.6710 | Validation Losses: y 0: 0.6936 | R2 Scores: y 0: 0.8652 | LR: 0.002
# 0.8638415932655334
# Epoch 816/1000 | Train Losses: y 0: 0.6656 | Validation Losses: y 0: 0.7158 | R2 Scores: y 0: 0.8638 | LR: 0.002
# 0.8568902015686035
# Epoch 817/1000 | Train Losses: y 0: 0.6841 | Validation Losses: y 0: 0.7811 | R2 Scores: y 0: 0.8569 | LR: 0.002
# 0.8816883563995361
# Epoch 818/1000 | Train Losses: y 0: 0.6698 | Validation Losses: y 0: 0.6741 | R2 Scores: y 0: 0.8817 | LR: 0.002
# 0.8782205581665039
# Epoch 819/1000 | Train Losses: y 0: 0.6932 | Validation Losses: y 0: 0.6624 | R2 Scores: y 0: 0.8782 | LR: 0.002
# 0.8553143739700317
# Epoch 820/1000 | Train Losses: y 0: 0.6697 | Validation Losses: y 0: 0.7636 | R2 Scores: y 0: 0.8553 | LR: 0.002
# Model saved at epoch 820 to /home/metz/deepchemometrics/Aioly_v2/Deep-Chemometrics/data/dataset/Mango/models/_DarioNet_Mango/_DarioNet_Mango_epoch_820.pth
# 0.8778360486030579
# Epoch 821/1000 | Train Losses: y 0: 0.6783 | Validation Losses: y 0: 0.6907 | R2 Scores: y 0: 0.8778 | LR: 0.002
# 0.850053608417511
# Epoch 822/1000 | Train Losses: y 0: 0.6716 | Validation Losses: y 0: 0.7913 | R2 Scores: y 0: 0.8501 | LR: 0.002
# 0.8518974781036377
# Epoch 823/1000 | Train Losses: y 0: 0.6828 | Validation Losses: y 0: 0.7456 | R2 Scores: y 0: 0.8519 | LR: 0.002
# 0.8716312050819397
# Epoch 824/1000 | Train Losses: y 0: 0.6529 | Validation Losses: y 0: 0.7112 | R2 Scores: y 0: 0.8716 | LR: 0.002
# 0.8366981744766235
# Epoch 825/1000 | Train Losses: y 0: 0.6927 | Validation Losses: y 0: 0.8106 | R2 Scores: y 0: 0.8367 | LR: 0.002
# 0.868832528591156
# Epoch 826/1000 | Train Losses: y 0: 0.6865 | Validation Losses: y 0: 0.7073 | R2 Scores: y 0: 0.8688 | LR: 0.002
# 0.8710581064224243
# Epoch 827/1000 | Train Losses: y 0: 0.7032 | Validation Losses: y 0: 0.7150 | R2 Scores: y 0: 0.8711 | LR: 0.002
# 0.8574367761611938
# Epoch 828/1000 | Train Losses: y 0: 0.6818 | Validation Losses: y 0: 0.7507 | R2 Scores: y 0: 0.8574 | LR: 0.002
# 0.8608144521713257
# Epoch 829/1000 | Train Losses: y 0: 0.6710 | Validation Losses: y 0: 0.8004 | R2 Scores: y 0: 0.8608 | LR: 0.002
# 0.8717780709266663
# Epoch 830/1000 | Train Losses: y 0: 0.6709 | Validation Losses: y 0: 0.6709 | R2 Scores: y 0: 0.8718 | LR: 0.002
# Model saved at epoch 830 to /home/metz/deepchemometrics/Aioly_v2/Deep-Chemometrics/data/dataset/Mango/models/_DarioNet_Mango/_DarioNet_Mango_epoch_830.pth
# 0.8564585447311401
# Epoch 831/1000 | Train Losses: y 0: 0.6773 | Validation Losses: y 0: 0.7661 | R2 Scores: y 0: 0.8565 | LR: 0.002
# 0.8701326251029968
# Epoch 832/1000 | Train Losses: y 0: 0.6923 | Validation Losses: y 0: 0.7124 | R2 Scores: y 0: 0.8701 | LR: 0.002
# 0.8681390881538391
# Epoch 833/1000 | Train Losses: y 0: 0.6839 | Validation Losses: y 0: 0.7382 | R2 Scores: y 0: 0.8681 | LR: 0.002
# 0.865903377532959
# Epoch 834/1000 | Train Losses: y 0: 0.6748 | Validation Losses: y 0: 0.7367 | R2 Scores: y 0: 0.8659 | LR: 0.002
# 0.8588258624076843
# Epoch 835/1000 | Train Losses: y 0: 0.6720 | Validation Losses: y 0: 0.7120 | R2 Scores: y 0: 0.8588 | LR: 0.002
# 0.8732041716575623
# Epoch 836/1000 | Train Losses: y 0: 0.6478 | Validation Losses: y 0: 0.6879 | R2 Scores: y 0: 0.8732 | LR: 0.002
# 0.855776309967041
# Epoch 837/1000 | Train Losses: y 0: 0.6897 | Validation Losses: y 0: 0.8353 | R2 Scores: y 0: 0.8558 | LR: 0.002
# 0.8396759033203125
# Epoch 838/1000 | Train Losses: y 0: 0.7123 | Validation Losses: y 0: 0.7631 | R2 Scores: y 0: 0.8397 | LR: 0.002
# 0.8474578857421875
# Epoch 839/1000 | Train Losses: y 0: 0.6947 | Validation Losses: y 0: 0.7999 | R2 Scores: y 0: 0.8475 | LR: 0.002
# 0.8652312159538269
# Epoch 840/1000 | Train Losses: y 0: 0.6826 | Validation Losses: y 0: 0.6906 | R2 Scores: y 0: 0.8652 | LR: 0.002
# Model saved at epoch 840 to /home/metz/deepchemometrics/Aioly_v2/Deep-Chemometrics/data/dataset/Mango/models/_DarioNet_Mango/_DarioNet_Mango_epoch_840.pth
# 0.8449426889419556
# Epoch 841/1000 | Train Losses: y 0: 0.6761 | Validation Losses: y 0: 0.7817 | R2 Scores: y 0: 0.8449 | LR: 0.002
# 0.8756207823753357
# Epoch 842/1000 | Train Losses: y 0: 0.6781 | Validation Losses: y 0: 0.6717 | R2 Scores: y 0: 0.8756 | LR: 0.002
# 0.8836479187011719
# Epoch 843/1000 | Train Losses: y 0: 0.7009 | Validation Losses: y 0: 0.6784 | R2 Scores: y 0: 0.8836 | LR: 0.002
# 0.8583507537841797
# Epoch 844/1000 | Train Losses: y 0: 0.6993 | Validation Losses: y 0: 0.7801 | R2 Scores: y 0: 0.8584 | LR: 0.002
# 0.8361698389053345
# Epoch 845/1000 | Train Losses: y 0: 0.6822 | Validation Losses: y 0: 0.7582 | R2 Scores: y 0: 0.8362 | LR: 0.002
# 0.8686231970787048
# Epoch 846/1000 | Train Losses: y 0: 0.6877 | Validation Losses: y 0: 0.7219 | R2 Scores: y 0: 0.8686 | LR: 0.002
# 0.8734418749809265
# Epoch 847/1000 | Train Losses: y 0: 0.6578 | Validation Losses: y 0: 0.7152 | R2 Scores: y 0: 0.8734 | LR: 0.002
# 0.8616192936897278
# Epoch 848/1000 | Train Losses: y 0: 0.6842 | Validation Losses: y 0: 0.7601 | R2 Scores: y 0: 0.8616 | LR: 0.002
# 0.884652853012085
# Epoch 849/1000 | Train Losses: y 0: 0.6821 | Validation Losses: y 0: 0.7088 | R2 Scores: y 0: 0.8847 | LR: 0.002
# 0.8606632947921753
# Epoch 850/1000 | Train Losses: y 0: 0.6784 | Validation Losses: y 0: 0.8096 | R2 Scores: y 0: 0.8607 | LR: 0.002
# Model saved at epoch 850 to /home/metz/deepchemometrics/Aioly_v2/Deep-Chemometrics/data/dataset/Mango/models/_DarioNet_Mango/_DarioNet_Mango_epoch_850.pth
# 0.8582726120948792
# Epoch 851/1000 | Train Losses: y 0: 0.6749 | Validation Losses: y 0: 0.7120 | R2 Scores: y 0: 0.8583 | LR: 0.002
# 0.8777621388435364
# Epoch 852/1000 | Train Losses: y 0: 0.6910 | Validation Losses: y 0: 0.6987 | R2 Scores: y 0: 0.8778 | LR: 0.002
# 0.8735427856445312
# Epoch 853/1000 | Train Losses: y 0: 0.6760 | Validation Losses: y 0: 0.6829 | R2 Scores: y 0: 0.8735 | LR: 0.002
# 0.8536784648895264
# Epoch 854/1000 | Train Losses: y 0: 0.6776 | Validation Losses: y 0: 0.8024 | R2 Scores: y 0: 0.8537 | LR: 0.002
# 0.8649740219116211
# Epoch 855/1000 | Train Losses: y 0: 0.6611 | Validation Losses: y 0: 0.7568 | R2 Scores: y 0: 0.8650 | LR: 0.002
# 0.8818236589431763
# Epoch 856/1000 | Train Losses: y 0: 0.6831 | Validation Losses: y 0: 0.6689 | R2 Scores: y 0: 0.8818 | LR: 0.002

# %%
print(max(val_r2_scores))
utils.test(model2,final_path,test_loader)

# %%
# création d'une boucle de prédiction pour réalisation du MC dropout
model2.eval()
model2.load_state_dict(torch.load(final_path))
model2.to("cuda")
dt = torch.Tensor(Xtest).to("cuda")
# création d'une boucle de 100 itérations pour réaliser le MC dropout
n_iter = 100
y_preds = []
for i in range(n_iter):
    with torch.no_grad():
        y_pred = model2.forward(dt[:, None])
    y_preds.append(y_pred)

y_preds = torch.stack(y_preds)

# moyenne des prédictions et écart type
y_pred = y_preds.mean(dim=0)
y_std = y_preds.std(dim=0)
# plot des prédiction en fonction des observations puis calcul du CCC, R2, etc
y_pred = np.squeeze(np.array(y_pred.detach().cpu()))
y_std = np.squeeze(np.array(y_std.detach().cpu()))
Ytest = np.squeeze(Ytest)
y_std = y_std.reshape(-1)


# Calcul des métriques
print("CCC: %5.5f, R2: %5.5f, RMSEP: %5.5f" % (ccc(y_pred, Ytest), r2_score(Ytest, y_pred), RMSEP(y_pred, Ytest)))

# plot des prédictions en fonction des observations avec l'écart-type en transparence avec plt.errorbar
plt.figure(figsize=(8,6))

# Scatter plot des observations et des prédictions
plt.scatter(Ytest, y_pred, edgecolors='k', alpha=0.5)

# Ajout des barres d'erreur représentant l'intervalle de confiance à 95%
plt.errorbar(Ytest, y_pred, yerr=1.9600 * y_std, fmt='o', color='r', alpha=0.2, label='95% confidence interval')

# Ligne rouge correspondant à y=x pour comparaison
plt.plot([Ytest.min() - 1, Ytest.max() + 1], [Ytest.min() - 1, Ytest.max() + 1], 'r')

# Ajout des métriques au graphique
plt.text(0.1 * Ytest.max(), 0.9 * Ytest.max(), 
         "CCC: %5.5f" % (ccc(Ytest, y_pred)) + "\nR2: %5.5f" % (r2_score(Ytest, y_pred)) + "\nRMSEP: %5.5f" % (RMSEP(Ytest, y_pred)),
         fontsize=16, bbox=dict(facecolor='white', alpha=0.5))

# Paramètres du graphique
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.xlabel('Observed', fontsize=16)
plt.ylabel('Predicted', fontsize=16)
plt.legend(fontsize=14)
plt.show(block=False)

# %%
model_name ="_CuiNet_Mango"  
spec_dims = x_cal.shape[1]
LR = 0.001
num_epochs = 1000
save_interval = 10
BATCH = 128
cal_loader = data_utils.DataLoader(cal, batch_size=BATCH, shuffle=True)
val_loader = data_utils.DataLoader(val, batch_size=BATCH, shuffle=True)
test_loader = data_utils.DataLoader(test_dt, batch_size=BATCH, shuffle=True)
data_path = "/home/metz/deepchemometrics/Aioly/data/dataset/Mango/mango_dm_full_outlier_removed2.mat"
save_path = os.path.dirname(os.path.abspath(data_path))+ f'/models/{model_name}/' + model_name

model = CuiNet(spec_dims, mean = mean,std = std, out_dims=1,dropout=0.02) 
optimizer = optim.Adam(model.parameters(), lr=LR)
criterion = nn.MSELoss(reduction='none')
print(model)

train_losses, val_losses,val_r2_scores, final_path =train(model, optimizer, criterion, cal_loader, val_loader, num_epochs, save_path=save_path, save_interval=save_interval, early_stop=False)

# %%
print(max(val_r2_scores))
utils.test(model,final_path,test_loader)

# %%
# création d'une boucle de prédiction pour réalisation du MC dropout
model.eval()
model.load_state_dict(torch.load(final_path))
model.to("cuda")
dt = torch.Tensor(Xtest).to("cuda")
# création d'une boucle de 100 itérations pour réaliser le MC dropout
n_iter = 1000
y_preds = []
for i in range(n_iter):
    with torch.no_grad():
        y_pred = model.forward(dt[:, None])
    y_preds.append(y_pred)

y_preds = torch.stack(y_preds)

# moyenne des prédictions et écart type
y_pred = y_preds.mean(dim=0)
y_std = y_preds.std(dim=0)
# plot des prédiction en fonction des observations puis calcul du CCC, R2, etc
y_pred = np.squeeze(np.array(y_pred.detach().cpu()))
y_std = np.squeeze(np.array(y_std.detach().cpu()))
Ytest = np.squeeze(Ytest)
y_std = y_std.reshape(-1)


# Calcul des métriques
print("CCC: %5.5f, R2: %5.5f, RMSEP: %5.5f" % (ccc(y_pred, Ytest), r2_score(Ytest, y_pred), RMSEP(y_pred, Ytest)))

# plot des prédictions en fonction des observations avec l'écart-type en transparence avec plt.errorbar
plt.figure(figsize=(8,6))

# Scatter plot des observations et des prédictions
plt.scatter(Ytest, y_pred, edgecolors='k', alpha=0.5)

# Ajout des barres d'erreur représentant l'intervalle de confiance à 95%
plt.errorbar(Ytest, y_pred, yerr=1.9600 * y_std, fmt='o', color='r', alpha=0.2, label='95% confidence interval')

# Ligne rouge correspondant à y=x pour comparaison
plt.plot([Ytest.min() - 1, Ytest.max() + 1], [Ytest.min() - 1, Ytest.max() + 1], 'r')

# Ajout des métriques au graphique
plt.text(0.1 * Ytest.max(), 0.9 * Ytest.max(), 
         "CCC: %5.5f" % (ccc(Ytest, y_pred)) + "\nR2: %5.5f" % (r2_score(Ytest, y_pred)) + "\nRMSEP: %5.5f" % (RMSEP(Ytest, y_pred)),
         fontsize=16, bbox=dict(facecolor='white', alpha=0.5))

# Paramètres du graphique
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.xlabel('Observed', fontsize=16)
plt.ylabel('Predicted', fontsize=16)
plt.legend(fontsize=14)
plt.show(block=False)

# %%
# Nombre de morceaux (bins) que tu veux pour diviser Ytest
n_bins = 30

# Découpage des données en bins selon les valeurs de Ytest
bins = np.linspace(Ytest.min(), Ytest.max(), n_bins+1)
indices = np.digitize(Ytest, bins)

# Initialisation des listes pour stocker les résultats
bin_centers = []
bin_rmse = []
bin_mean_std = []  # Moyenne des écarts-types dans chaque bin

# Calcul de l'erreur (RMSE) et de l'écart-type moyen dans chaque bin
for i in range(1, n_bins+1):
    # Sélection des indices des données appartenant au bin courant
    bin_indices = np.where(indices == i)[0]
    
    if len(bin_indices) > 0:  # Vérification qu'il y a des points dans ce bin
        y_pred_bin = y_pred[bin_indices]
        Ytest_bin = Ytest[bin_indices]
        y_std_bin = y_std[bin_indices]
        
        # Calcul du RMSE dans ce bin
        rmse = np.sqrt(RMSEP(Ytest_bin, y_pred_bin))
        
        # Calcul de l'écart-type moyen dans ce bin
        mean_std = np.mean(y_std_bin)
        
        # Centre du bin (pour l'axe des x)
        bin_center = (bins[i-1] + bins[i]) / 2
        
        # Stocker les résultats
        bin_centers.append(bin_center)
        bin_rmse.append(rmse)
        bin_mean_std.append(mean_std)

# Tracé de l'erreur par bin (RMSE et écart-type moyen)
plt.figure(figsize=(10,6))

# Tracé du RMSE par bin
plt.plot(bin_centers, bin_rmse, marker='o', linestyle='-', color='b', label='RMSE')

# Ajout de la bande d'incertitude autour de la ligne de RMSE (RMSE ± moyenne des écarts-types)
plt.fill_between(bin_centers, 
                 np.array(bin_rmse) - np.array(bin_mean_std), 
                 np.array(bin_rmse) + np.array(bin_mean_std), 
                 color='blue', alpha=0.2, label='RMSE ± Std Deviation')

# Ajout des labels et de la légende
plt.xlabel('Value of Ytest (bin center)', fontsize=16)
plt.ylabel('Error', fontsize=16)
plt.title('Global Estimation of Error by Bin with Confidence Bands', fontsize=16)
plt.legend(fontsize=14)
plt.grid(True)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %%
n_iter = 1000
y_preds = []
for i in range(n_iter):
    with torch.no_grad():
        y_pred = model.forward(dt[:, None])
    y_preds.append(y_pred)

y_preds = torch.stack(y_preds)

# moyenne des prédictions et écart type
y_pred1 = y_preds.mean(dim=0)
y_std1= y_preds.std(dim=0)
# plot des prédiction en fonction des observations puis calcul du CCC, R2, etc
y_pred1 = np.squeeze(np.array(y_pred1.detach().cpu()))
y_std1 = np.squeeze(np.array(y_std1.detach().cpu()))
Ytest = np.squeeze(Ytest)
y_std1 = y_std1.reshape(-1)

n_iter = 1000
y_preds = []
for i in range(n_iter):
    with torch.no_grad():
        y_pred = model2.forward(dt[:, None])
    y_preds.append(y_pred)

y_preds = torch.stack(y_preds)

# moyenne des prédictions et écart type
y_pred2 = y_preds.mean(dim=0)
y_std2= y_preds.std(dim=0)
# plot des prédiction en fonction des observations puis calcul du CCC, R2, etc
y_pred2 = np.squeeze(np.array(y_pred2.detach().cpu()))
y_std2 = np.squeeze(np.array(y_std2.detach().cpu()))
y_std2 = y_std2.reshape(-1)
print(RMSEP(Ytest,y_pred2))

# Nombre de morceaux (bins) pour diviser Ytest
n_bins = 30

# Découpage des données en bins selon les valeurs de Ytest
bins = np.linspace(Ytest.min(), Ytest.max(), n_bins+1)
indices = np.digitize(Ytest, bins)

# Initialisation des listes pour stocker les résultats pour y_pred1 et y_pred2
bin_centers = []
bin_rmse1 = []
bin_rmse2 = []
bin_mean_std1 = []  # Moyenne des écarts-types pour y_pred1 dans chaque bin
bin_mean_std2 = []  # Moyenne des écarts-types pour y_pred2 dans chaque bin

# Calcul de l'erreur (RMSE) et de l'écart-type moyen dans chaque bin
for i in range(1, n_bins+1):
    # Sélection des indices des données appartenant au bin courant
    bin_indices = np.where(indices == i)[0]
    
    if len(bin_indices) > 0:  # Vérification qu'il y a des points dans ce bin
        # Données pour le bin courant
        Ytest_bin = Ytest[bin_indices]
        
        # Prédiction 1
        y_pred_bin1 = y_pred1[bin_indices]
        y_std_bin1 = y_std1[bin_indices]  # Ecart-type pour y_pred1
        rmse1 = np.sqrt(RMSEP(Ytest_bin, y_pred_bin1))
        mean_std1 = np.mean(y_std_bin1)
        
        # Prédiction 2
        y_pred_bin2 = y_pred2[bin_indices]
        y_std_bin2 = y_std2[bin_indices]  # Ecart-type pour y_pred2
        rmse2 = np.sqrt(RMSEP(Ytest_bin, y_pred_bin2))
        mean_std2 = np.mean(y_std_bin2)
        
        # Centre du bin (pour l'axe des x)
        bin_center = (bins[i-1] + bins[i]) / 2
        
        # Stocker les résultats
        bin_centers.append(bin_center)
        bin_rmse1.append(rmse1)
        bin_mean_std1.append(mean_std1)
        bin_rmse2.append(rmse2)
        bin_mean_std2.append(mean_std2)

# Tracé des erreurs par bin pour y_pred1 et y_pred2
plt.figure(figsize=(10,6))

# Tracé du RMSE par bin pour y_pred1
plt.plot(bin_centers, bin_rmse1, marker='o', linestyle='-', color='b', label='RMSE y_pred1')
plt.fill_between(bin_centers, 
                 np.array(bin_rmse1) - np.array(bin_mean_std1), 
                 np.array(bin_rmse1) + np.array(bin_mean_std1), 
                 color='blue', alpha=0.2, label='RMSE ± Std Deviation y_pred1')

# Tracé du RMSE par bin pour y_pred2
plt.plot(bin_centers, bin_rmse2, marker='o', linestyle='-', color='r', label='RMSE y_pred2')
plt.fill_between(bin_centers, 
                 np.array(bin_rmse2) - np.array(bin_mean_std2), 
                 np.array(bin_rmse2) + np.array(bin_mean_std2), 
                 color='red', alpha=0.2, label='RMSE ± Std Deviation y_pred2')

# Ajout des labels et de la légende
plt.xlabel('Value of Ytest (bin center)', fontsize=16)
plt.ylabel('Error', fontsize=16)
plt.title('Global Estimation of Error by Bin for y_pred1 and y_pred2', fontsize=16)
plt.legend(fontsize=14)
plt.grid(True)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()
